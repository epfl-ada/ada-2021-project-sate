# %% [markdown]
# # TO RUN : imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import bz2
import urllib
from datetime import datetime, date

data_folder = 'data/'

# %% [markdown]
# # SELECT DATA OF INTEREST
# The project focusing on the debate of the right to bear arms in the USA, the first task consists in selecting the data related to this topic. To do so, we use a lexical field (named ***lexical_field*** in the code)  related to the topic, and select only the quotations, which contain one or more words of this lexical field. <br> The determined word bank is the set of the following words: 'gun', 'firearm', 'mass shooting', '2nd Amendment', 'homicide', 'gun shot', 'armed robbery', 'rifles', 'Second Amendment', 'Columbine', 'gun control'. The way the words have been chosen is explained in the `read.me`.  <br> <br>
# The selected quotes are then stored in a new data file named `quotes-20__-extended.json.bz2` in form of a dataframe with new columns. The added columns contain information about the speakers (gender, nationality, occupations, age (computed from the date of birth), ethnic group, political party and religion). Such information are taken from the second dataset `speaker_attributes.parquet`, built from wikidata information. Quotations that are not related to any seaker are not kept. <br> <br>
# This data preprocessing being long, we decide to only treat the quotations of 2017 for Milestone 2. The corresponding file have a total of more than 26 millions quotes, it contains way enough infomation to compute the first statistics and check if our project is feasible. <br>
# This is also why we decide to save the most information possible about the speaker. The quotations from the other years will be studied in Milestone 3.  <br> <br>

# %%
lexical_field = ['mass shooting','gun control','gun violence','2nd amendment','second amendment','gun owning','firearm']

speakers = pd.read_parquet(data_folder + 'speaker_attributes.parquet')
label = pd.read_csv(data_folder + 'wikidata_labels_descriptions_quotebank.csv.bz2', compression='bz2', index_col='QID')

# %%
path_to_file = data_folder + 'quotes-2018.json.bz2' 
path_to_out = data_folder + 'quotes-2018-extended.json.bz2'

iter = 0
nb_occ = 0

with bz2.open(path_to_file, 'rb') as s_file:
    with bz2.open(path_to_out, 'wb') as d_file:
        for instance in s_file:
            instance = json.loads(instance) # loading a sample
            
            #To count the number of citations
            iter += 1
            
            #To count the total number of occurences
            if instance['numOccurrences'] is not None:
                nb_occ += instance['numOccurrences']

            #To check the progress of the algorithm, because it takes multiple hours to run
            if (iter % 100000 == 0):
                print('nombre de citations lus: {}'.format(iter))

            #We check if the quotation contains words from the lexical field
            if any(substring.lower() in instance['quotation'].lower() for substring in lexical_field) and instance['qids'] != []: #We keep only quotation containing words of the lexical field and where there is a speaker
                
                #We load additional information about the speaker
                speaker = speakers.loc[speakers['id'] == instance['qids'][0]].squeeze()

                #We add nationality
                if speaker.nationality is not None:
                    instance['nationality'] = []
                    for i in speaker['nationality']:
                        nat = label.loc[i]['Label']
                        instance['nationality'].append(nat)
                else:
                    instance['nationality'] = None
                    
                #We add the gender
                if speaker.gender is not None:
                    instance['gender'] = []
                    for i in speaker['gender']:
                        gend = label.loc[i]['Label']
                        instance['gender'].append(gend)
                else:
                    instance['gender'] = None

                #We add the occupations
                
                if speaker.occupation is not None:
                    instance['occupation'] = []
                    for i in speaker['occupation']:
                        if i != 'Q99753484':
                            occ = label.loc[i]['Label']
                            instance['occupation'].append(occ)
                else:
                    instance['occupation'] = None
                    
#                 if speaker.occupation is not None:
#                     instance['occupation'] = []
#                     for i in speaker['occupation']:
#                         occ = label.loc[i]['Label']
#                         instance['occupation'].append(occ)
#                 else:
#                     instance['occupation'] = None

                #We add the age (computed from the date of birth)
                #We use a try since the date is wrong (e.g. month = 0) at some places
                try:
                    born = datetime.strptime(speaker.date_of_birth[0][1:11], "%Y-%m-%d").date()
                    today = date.today()
                    age = today.year - born.year - ((today.month, today.day) < (born.month, born.day))
                except:
                    age = None
                instance['age'] = age

                #We add the ethnic group
                if speaker.ethnic_group is not None:
                    instance['ethnic_group'] = []
                    for i in speaker['ethnic_group']:
                        ethnic = label.loc[i]['Label']
                        instance['ethnic_group'].append(ethnic)
                else:
                    instance['ethnic_group'] = None

                #We add the party
                if speaker.party is not None:
                    instance['party'] = []
                    for i in speaker['party']:
                        part = label.loc[i]['Label']
                        instance['party'].append(part)
                else:
                    instance['party'] = None

                #We add the religion
                if speaker.religion is not None:
                    instance['religion'] = []
                    for i in speaker['religion']:
                        relig = label.loc[i]['Label']
                        instance['religion'].append(relig)
                else:
                    instance['religion'] = None

                d_file.write((json.dumps(instance)+'\n').encode('utf-8')) # writing in the new file


print('iter = {i}'.format(i = iter))
print('nb_occ = {n}'.format(n = nb_occ))
# Out:
# nombre de citations lus: 100000
# nombre de citations lus: 200000
# nombre de citations lus: 300000
# nombre de citations lus: 400000
# nombre de citations lus: 500000
# nombre de citations lus: 600000
# nombre de citations lus: 700000
# nombre de citations lus: 800000
# nombre de citations lus: 900000
# nombre de citations lus: 1000000
# nombre de citations lus: 1100000
# nombre de citations lus: 1200000
# nombre de citations lus: 1300000
# nombre de citations lus: 1400000
# nombre de citations lus: 1500000
# nombre de citations lus: 1600000
# nombre de citations lus: 1700000
# nombre de citations lus: 1800000
# nombre de citations lus: 1900000
# nombre de citations lus: 2000000
# nombre de citations lus: 2100000
# nombre de citations lus: 2200000
# nombre de citations lus: 2300000
# nombre de citations lus: 2400000
# nombre de citations lus: 2500000
# nombre de citations lus: 2600000
# nombre de citations lus: 2700000
# nombre de citations lus: 2800000
# nombre de citations lus: 2900000
# nombre de citations lus: 3000000
# nombre de citations lus: 3100000
# nombre de citations lus: 3200000
# nombre de citations lus: 3300000
# nombre de citations lus: 3400000
# nombre de citations lus: 3500000
# nombre de citations lus: 3600000
# nombre de citations lus: 3700000
# nombre de citations lus: 3800000
# nombre de citations lus: 3900000
# nombre de citations lus: 4000000
# nombre de citations lus: 4100000
# nombre de citations lus: 4200000
# nombre de citations lus: 4300000
# nombre de citations lus: 4400000
# nombre de citations lus: 4500000
# nombre de citations lus: 4600000
# nombre de citations lus: 4700000
# nombre de citations lus: 4800000
# nombre de citations lus: 4900000
# nombre de citations lus: 5000000
# nombre de citations lus: 5100000
# nombre de citations lus: 5200000
# nombre de citations lus: 5300000
# nombre de citations lus: 5400000
# nombre de citations lus: 5500000
# nombre de citations lus: 5600000
# nombre de citations lus: 5700000
# nombre de citations lus: 5800000
# nombre de citations lus: 5900000
# nombre de citations lus: 6000000
# nombre de citations lus: 6100000
# nombre de citations lus: 6200000
# nombre de citations lus: 6300000
# nombre de citations lus: 6400000
# nombre de citations lus: 6500000
# nombre de citations lus: 6600000
# nombre de citations lus: 6700000
# nombre de citations lus: 6800000
# nombre de citations lus: 6900000
# nombre de citations lus: 7000000
# nombre de citations lus: 7100000
# nombre de citations lus: 7200000
# nombre de citations lus: 7300000
# nombre de citations lus: 7400000
# nombre de citations lus: 7500000
# nombre de citations lus: 7600000
# nombre de citations lus: 7700000
# nombre de citations lus: 7800000
# nombre de citations lus: 7900000
# nombre de citations lus: 8000000
# nombre de citations lus: 8100000
# nombre de citations lus: 8200000
# nombre de citations lus: 8300000
# nombre de citations lus: 8400000
# nombre de citations lus: 8500000
# nombre de citations lus: 8600000
# nombre de citations lus: 8700000
# nombre de citations lus: 8800000
# nombre de citations lus: 8900000
# nombre de citations lus: 9000000
# nombre de citations lus: 9100000
# nombre de citations lus: 9200000
# nombre de citations lus: 9300000
# nombre de citations lus: 9400000
# nombre de citations lus: 9500000
# nombre de citations lus: 9600000
# nombre de citations lus: 9700000
# nombre de citations lus: 9800000
# nombre de citations lus: 9900000
# nombre de citations lus: 10000000
# nombre de citations lus: 10100000
# nombre de citations lus: 10200000
# nombre de citations lus: 10300000
# nombre de citations lus: 10400000
# nombre de citations lus: 10500000
# nombre de citations lus: 10600000
# nombre de citations lus: 10700000
# nombre de citations lus: 10800000
# nombre de citations lus: 10900000
# nombre de citations lus: 11000000
# nombre de citations lus: 11100000
# nombre de citations lus: 11200000
# nombre de citations lus: 11300000
# nombre de citations lus: 11400000
# nombre de citations lus: 11500000
# nombre de citations lus: 11600000
# nombre de citations lus: 11700000
# nombre de citations lus: 11800000
# nombre de citations lus: 11900000
# nombre de citations lus: 12000000
# nombre de citations lus: 12100000
# nombre de citations lus: 12200000
# nombre de citations lus: 12300000
# nombre de citations lus: 12400000
# nombre de citations lus: 12500000
# nombre de citations lus: 12600000
# nombre de citations lus: 12700000
# nombre de citations lus: 12800000
# nombre de citations lus: 12900000
# nombre de citations lus: 13000000
# nombre de citations lus: 13100000
# nombre de citations lus: 13200000
# nombre de citations lus: 13300000
# nombre de citations lus: 13400000
# nombre de citations lus: 13500000
# nombre de citations lus: 13600000
# nombre de citations lus: 13700000
# nombre de citations lus: 13800000
# nombre de citations lus: 13900000
# nombre de citations lus: 14000000
# nombre de citations lus: 14100000
# nombre de citations lus: 14200000
# nombre de citations lus: 14300000
# nombre de citations lus: 14400000
# nombre de citations lus: 14500000
# nombre de citations lus: 14600000
# nombre de citations lus: 14700000
# nombre de citations lus: 14800000
# nombre de citations lus: 14900000
# nombre de citations lus: 15000000
# nombre de citations lus: 15100000
# nombre de citations lus: 15200000
# nombre de citations lus: 15300000
# nombre de citations lus: 15400000
# nombre de citations lus: 15500000
# nombre de citations lus: 15600000
# nombre de citations lus: 15700000
# nombre de citations lus: 15800000
# nombre de citations lus: 15900000
# nombre de citations lus: 16000000
# nombre de citations lus: 16100000
# nombre de citations lus: 16200000
# nombre de citations lus: 16300000
# nombre de citations lus: 16400000
# nombre de citations lus: 16500000
# nombre de citations lus: 16600000
# nombre de citations lus: 16700000
# nombre de citations lus: 16800000
# nombre de citations lus: 16900000
# nombre de citations lus: 17000000
# nombre de citations lus: 17100000
# nombre de citations lus: 17200000
# nombre de citations lus: 17300000
# nombre de citations lus: 17400000
# nombre de citations lus: 17500000
# nombre de citations lus: 17600000
# nombre de citations lus: 17700000
# nombre de citations lus: 17800000
# nombre de citations lus: 17900000
# nombre de citations lus: 18000000
# nombre de citations lus: 18100000
# nombre de citations lus: 18200000
# nombre de citations lus: 18300000
# nombre de citations lus: 18400000
# nombre de citations lus: 18500000
# nombre de citations lus: 18600000
# nombre de citations lus: 18700000
# nombre de citations lus: 18800000
# nombre de citations lus: 18900000
# nombre de citations lus: 19000000
# nombre de citations lus: 19100000
# nombre de citations lus: 19200000
# nombre de citations lus: 19300000
# nombre de citations lus: 19400000
# nombre de citations lus: 19500000
# nombre de citations lus: 19600000
# nombre de citations lus: 19700000
# nombre de citations lus: 19800000
# nombre de citations lus: 19900000
# nombre de citations lus: 20000000
# nombre de citations lus: 20100000
# nombre de citations lus: 20200000
# nombre de citations lus: 20300000
# nombre de citations lus: 20400000
# nombre de citations lus: 20500000
# nombre de citations lus: 20600000
# nombre de citations lus: 20700000
# nombre de citations lus: 20800000
# nombre de citations lus: 20900000
# nombre de citations lus: 21000000
# nombre de citations lus: 21100000
# nombre de citations lus: 21200000
# nombre de citations lus: 21300000
# nombre de citations lus: 21400000
# nombre de citations lus: 21500000
# nombre de citations lus: 21600000
# nombre de citations lus: 21700000
# nombre de citations lus: 21800000
# nombre de citations lus: 21900000
# nombre de citations lus: 22000000
# nombre de citations lus: 22100000
# nombre de citations lus: 22200000
# nombre de citations lus: 22300000
# nombre de citations lus: 22400000
# nombre de citations lus: 22500000
# nombre de citations lus: 22600000
# nombre de citations lus: 22700000
# nombre de citations lus: 22800000
# nombre de citations lus: 22900000
# nombre de citations lus: 23000000
# nombre de citations lus: 23100000
# nombre de citations lus: 23200000
# nombre de citations lus: 23300000
# nombre de citations lus: 23400000
# nombre de citations lus: 23500000
# nombre de citations lus: 23600000
# nombre de citations lus: 23700000
# nombre de citations lus: 23800000
# nombre de citations lus: 23900000
# nombre de citations lus: 24000000
# nombre de citations lus: 24100000
# nombre de citations lus: 24200000
# nombre de citations lus: 24300000
# nombre de citations lus: 24400000
# nombre de citations lus: 24500000
# nombre de citations lus: 24600000
# nombre de citations lus: 24700000
# nombre de citations lus: 24800000
# nombre de citations lus: 24900000
# nombre de citations lus: 25000000
# nombre de citations lus: 25100000
# nombre de citations lus: 25200000
# nombre de citations lus: 25300000
# nombre de citations lus: 25400000
# nombre de citations lus: 25500000
# nombre de citations lus: 25600000
# nombre de citations lus: 25700000
# nombre de citations lus: 25800000
# nombre de citations lus: 25900000
# nombre de citations lus: 26000000
# nombre de citations lus: 26100000
# nombre de citations lus: 26200000
# nombre de citations lus: 26300000
# nombre de citations lus: 26400000
# nombre de citations lus: 26500000
# nombre de citations lus: 26600000
# nombre de citations lus: 26700000
# nombre de citations lus: 26800000
# nombre de citations lus: 26900000
# nombre de citations lus: 27000000
# nombre de citations lus: 27100000
# nombre de citations lus: 27200000
# iter = 27228451
# nb_occ = 113316534

# %% [markdown]
# **Useful statistics :**
# **2016:**
# Number of "different" quotes in the 2016 newpapers: 13 862 129.
# Some of these quotes being mentionned in several articles (number of occurence >1), the total number of quotes in 2016 is: 136 326 717.
#
# **2017:**
# Number of "different" quotes in the 2017 newpapers:  (avant: 26 611 588).
# Some of these quotes being mentionned in several articles (number of occurence >1), the total number of quotes in 2017 is: (avant: 136 326 717).

# %% [markdown]
# **2018:**
# Number of "different" quotes in the 2018 newpapers:  27228451.
# Some of these quotes being mentionned in several articles (number of occurence >1), the total number of quotes in 2018 is: 113316534.
#
# **2019:**
# Number of "different" quotes in the 2019 newpapers: 21 763 302.
# Some of these quotes being mentionned in several articles (number of occurence >1), the total number of quotes in 2019 is: 74 058 561.
#
# **2020:**
# Number of "different" quotes in the 2020 newpapers: .
# Some of these quotes being mentionned in several articles (number of occurence >1), the total number of quotes in 2020 is: .
